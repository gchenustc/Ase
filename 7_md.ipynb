# %%
# NVE
from ase.lattice.cubic import FaceCenteredCubic
from ase.visualize import view
from ase.calculators.emt import EMT
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution
# We want to run MD with constant energy using the VelocityVerlet algorithm.
from ase.md.verlet import VelocityVerlet
from ase import units
size = 3 # 扩胞倍数
atoms = FaceCenteredCubic(directions=[[1, 0, 0], [0, 1, 0], [0, 0, 1]],
                          symbol='Cu',
                          size=(size, size, size), # 扩胞倍数
                          pbc=True)
# view(atoms)
atoms.calc = EMT()
# 设定温度 - 给定一个初始速度
MaxwellBoltzmannDistribution(atoms, temperature_K=300)
# 设定时间 5 fs / step
dyn = VelocityVerlet(atoms, 5*units.fs, trajectory="md1.traj")

def printenergy(a = atoms):
    """Function to print the potential, kinetic and total energy"""
    epot = a.get_potential_energy() / len(a)
    ekin = a.get_kinetic_energy() / len(a)
    print('Energy per atom: Epot = %.3feV  Ekin = %.3feV (T=%3.0fK)  '
          'Etot = %.3feV' % (epot, ekin, ekin / (1.5 * units.kB), epot + ekin))

# 每 10 步 执行一次 printenergy
dyn.attach(printenergy, interval=10)
dyn.run(200)
# Out:
# Energy per atom: Epot = -0.006eV  Ekin = 0.036eV (T=280K)  Etot = 0.031eV
# Energy per atom: Epot = -0.006eV  Ekin = 0.036eV (T=280K)  Etot = 0.031eV
# Energy per atom: Epot = 0.023eV  Ekin = 0.007eV (T= 56K)  Etot = 0.031eV
# Energy per atom: Epot = 0.012eV  Ekin = 0.019eV (T=144K)  Etot = 0.031eV
# Energy per atom: Epot = 0.012eV  Ekin = 0.019eV (T=148K)  Etot = 0.031eV
# Energy per atom: Epot = 0.009eV  Ekin = 0.021eV (T=166K)  Etot = 0.031eV
# Energy per atom: Epot = 0.013eV  Ekin = 0.018eV (T=139K)  Etot = 0.031eV
# Energy per atom: Epot = 0.017eV  Ekin = 0.014eV (T=109K)  Etot = 0.031eV
# Energy per atom: Epot = 0.008eV  Ekin = 0.022eV (T=173K)  Etot = 0.031eV
# Energy per atom: Epot = 0.014eV  Ekin = 0.017eV (T=128K)  Etot = 0.031eV
# Energy per atom: Epot = 0.010eV  Ekin = 0.021eV (T=160K)  Etot = 0.031eV
# Energy per atom: Epot = 0.014eV  Ekin = 0.017eV (T=129K)  Etot = 0.031eV
# Energy per atom: Epot = 0.013eV  Ekin = 0.018eV (T=137K)  Etot = 0.031eV
# Energy per atom: Epot = 0.012eV  Ekin = 0.018eV (T=141K)  Etot = 0.031eV
# Energy per atom: Epot = 0.008eV  Ekin = 0.022eV (T=173K)  Etot = 0.031eV
# Energy per atom: Epot = 0.018eV  Ekin = 0.012eV (T= 95K)  Etot = 0.031eV
# Energy per atom: Epot = 0.009eV  Ekin = 0.022eV (T=169K)  Etot = 0.031eV
# Energy per atom: Epot = 0.014eV  Ekin = 0.016eV (T=126K)  Etot = 0.031eV
# Energy per atom: Epot = 0.012eV  Ekin = 0.019eV (T=148K)  Etot = 0.031eV
# Energy per atom: Epot = 0.013eV  Ekin = 0.017eV (T=135K)  Etot = 0.031eV
# Energy per atom: Epot = 0.013eV  Ekin = 0.018eV (T=140K)  Etot = 0.031eV
# Energy per atom: Epot = 0.012eV  Ekin = 0.019eV (T=147K)  Etot = 0.031eV
# True

# %%
# NVT
"""Demonstrates molecular dynamics with constant temperature."""
from ase.lattice.cubic import FaceCenteredCubic
from ase.md.langevin import Langevin
from ase.io.trajectory import Trajectory
from ase import units
from ase.calculators.emt import EMT
size = 3

T = 1500  # Kelvin

# Set up a crystal
atoms = FaceCenteredCubic(directions=[[1, 0, 0], [0, 1, 0], [0, 0, 1]],
                          symbol="Cu",
                          size=(size, size, size),
                          pbc=False)

# Describe the interatomic interactions with the Effective Medium Theory
atoms.calc = EMT()

# We want to run MD with constant energy using the Langevin algorithm
# with a time step of 5 fs, the temperature T and the friction
# coefficient to 0.02 atomic units.
dyn = Langevin(atoms, 5 * units.fs, T * units.kB, 0.002, logfile="moldyn3.log")


def printenergy(a=atoms):  # store a reference to atoms in the definition.
    """Function to print the potential, kinetic and total energy."""
    epot = a.get_potential_energy() / len(a)
    ekin = a.get_kinetic_energy() / len(a)
    print('Energy per atom: Epot = %.3feV  Ekin = %.3feV (T=%3.0fK)  '
          'Etot = %.3feV' % (epot, ekin, ekin / (1.5 * units.kB), epot + ekin))


dyn.attach(printenergy, interval=50)

# We also want to save the positions of all atoms after every 100th time step.
traj = Trajectory('moldyn3.traj', 'w', atoms)
dyn.attach(traj.write, interval=50)

# Now run the dynamics
dyn.run(5000)
# Out:
# Energy per atom: Epot = 0.441eV  Ekin = 0.000eV (T=  0K)  Etot = 0.441eV
# Energy per atom: Epot = 0.441eV  Ekin = 0.000eV (T=  0K)  Etot = 0.441eV
# Energy per atom: Epot = 0.439eV  Ekin = 0.021eV (T=164K)  Etot = 0.460eV
# Energy per atom: Epot = 0.448eV  Ekin = 0.028eV (T=218K)  Etot = 0.476eV
# Energy per atom: Epot = 0.456eV  Ekin = 0.035eV (T=270K)  Etot = 0.490eV
# Energy per atom: Epot = 0.465eV  Ekin = 0.042eV (T=321K)  Etot = 0.507eV
# Energy per atom: Epot = 0.473eV  Ekin = 0.051eV (T=391K)  Etot = 0.523eV
# Energy per atom: Epot = 0.484eV  Ekin = 0.054eV (T=417K)  Etot = 0.538eV
# Energy per atom: Epot = 0.483eV  Ekin = 0.070eV (T=545K)  Etot = 0.553eV
# Energy per atom: Epot = 0.499eV  Ekin = 0.068eV (T=524K)  Etot = 0.567eV
# Energy per atom: Epot = 0.511eV  Ekin = 0.074eV (T=570K)  Etot = 0.585eV
# Energy per atom: Epot = 0.517eV  Ekin = 0.087eV (T=672K)  Etot = 0.604eV
# Energy per atom: Epot = 0.518eV  Ekin = 0.097eV (T=754K)  Etot = 0.616eV
# Energy per atom: Epot = 0.533eV  Ekin = 0.095eV (T=737K)  Etot = 0.628eV
# Energy per atom: Epot = 0.545eV  Ekin = 0.091eV (T=703K)  Etot = 0.636eV
# Energy per atom: Epot = 0.540eV  Ekin = 0.113eV (T=871K)  Etot = 0.652eV
# Energy per atom: Epot = 0.550eV  Ekin = 0.114eV (T=879K)  Etot = 0.664eV
# Energy per atom: Epot = 0.562eV  Ekin = 0.107eV (T=832K)  Etot = 0.670eV
# Energy per atom: Epot = 0.568eV  Ekin = 0.112eV (T=869K)  Etot = 0.681eV
# Energy per atom: Epot = 0.579eV  Ekin = 0.115eV (T=890K)  Etot = 0.694eV
# Energy per atom: Epot = 0.576eV  Ekin = 0.130eV (T=1009K)  Etot = 0.706eV
# Energy per atom: Epot = 0.580eV  Ekin = 0.134eV (T=1035K)  Etot = 0.714eV
# Energy per atom: Epot = 0.589eV  Ekin = 0.123eV (T=949K)  Etot = 0.711eV
# Energy per atom: Epot = 0.591eV  Ekin = 0.123eV (T=951K)  Etot = 0.714eV
# Energy per atom: Epot = 0.596eV  Ekin = 0.133eV (T=1027K)  Etot = 0.729eV
# Energy per atom: Epot = 0.599eV  Ekin = 0.132eV (T=1020K)  Etot = 0.730eV
# Energy per atom: Epot = 0.589eV  Ekin = 0.137eV (T=1056K)  Etot = 0.726eV
# Energy per atom: Epot = 0.602eV  Ekin = 0.138eV (T=1069K)  Etot = 0.740eV
# Energy per atom: Epot = 0.609eV  Ekin = 0.140eV (T=1085K)  Etot = 0.749eV
# Energy per atom: Epot = 0.633eV  Ekin = 0.118eV (T=913K)  Etot = 0.751eV
# Energy per atom: Epot = 0.607eV  Ekin = 0.141eV (T=1091K)  Etot = 0.748eV
# Energy per atom: Epot = 0.632eV  Ekin = 0.130eV (T=1007K)  Etot = 0.762eV
# Energy per atom: Epot = 0.614eV  Ekin = 0.155eV (T=1202K)  Etot = 0.770eV
# Energy per atom: Epot = 0.618eV  Ekin = 0.156eV (T=1207K)  Etot = 0.774eV
# Energy per atom: Epot = 0.617eV  Ekin = 0.161eV (T=1244K)  Etot = 0.778eV
# Energy per atom: Epot = 0.637eV  Ekin = 0.146eV (T=1129K)  Etot = 0.783eV
# Energy per atom: Epot = 0.623eV  Ekin = 0.165eV (T=1274K)  Etot = 0.788eV
# Energy per atom: Epot = 0.650eV  Ekin = 0.147eV (T=1134K)  Etot = 0.797eV
# Energy per atom: Epot = 0.658eV  Ekin = 0.135eV (T=1043K)  Etot = 0.793eV
# Energy per atom: Epot = 0.633eV  Ekin = 0.169eV (T=1311K)  Etot = 0.803eV
# Energy per atom: Epot = 0.661eV  Ekin = 0.151eV (T=1170K)  Etot = 0.812eV
# Energy per atom: Epot = 0.650eV  Ekin = 0.157eV (T=1214K)  Etot = 0.807eV
# Energy per atom: Epot = 0.665eV  Ekin = 0.147eV (T=1140K)  Etot = 0.812eV
# Energy per atom: Epot = 0.654eV  Ekin = 0.160eV (T=1234K)  Etot = 0.814eV
# Energy per atom: Epot = 0.695eV  Ekin = 0.119eV (T=920K)  Etot = 0.814eV
# Energy per atom: Epot = 0.664eV  Ekin = 0.155eV (T=1196K)  Etot = 0.819eV
# Energy per atom: Epot = 0.656eV  Ekin = 0.175eV (T=1351K)  Etot = 0.831eV
# Energy per atom: Epot = 0.682eV  Ekin = 0.152eV (T=1172K)  Etot = 0.834eV
# Energy per atom: Epot = 0.683eV  Ekin = 0.157eV (T=1211K)  Etot = 0.839eV
# Energy per atom: Epot = 0.665eV  Ekin = 0.174eV (T=1343K)  Etot = 0.839eV
# Energy per atom: Epot = 0.686eV  Ekin = 0.166eV (T=1281K)  Etot = 0.851eV
# Energy per atom: Epot = 0.674eV  Ekin = 0.177eV (T=1368K)  Etot = 0.851eV
# Energy per atom: Epot = 0.671eV  Ekin = 0.179eV (T=1383K)  Etot = 0.849eV
# Energy per atom: Epot = 0.672eV  Ekin = 0.177eV (T=1371K)  Etot = 0.849eV
# Energy per atom: Epot = 0.666eV  Ekin = 0.186eV (T=1437K)  Etot = 0.852eV
# Energy per atom: Epot = 0.680eV  Ekin = 0.173eV (T=1339K)  Etot = 0.853eV
# Energy per atom: Epot = 0.691eV  Ekin = 0.160eV (T=1240K)  Etot = 0.851eV
# Energy per atom: Epot = 0.702eV  Ekin = 0.151eV (T=1171K)  Etot = 0.853eV
# Energy per atom: Epot = 0.692eV  Ekin = 0.163eV (T=1263K)  Etot = 0.855eV
# Energy per atom: Epot = 0.681eV  Ekin = 0.175eV (T=1356K)  Etot = 0.856eV
# Energy per atom: Epot = 0.679eV  Ekin = 0.188eV (T=1453K)  Etot = 0.867eV
# Energy per atom: Epot = 0.696eV  Ekin = 0.177eV (T=1372K)  Etot = 0.873eV
# Energy per atom: Epot = 0.701eV  Ekin = 0.180eV (T=1393K)  Etot = 0.881eV
# Energy per atom: Epot = 0.702eV  Ekin = 0.184eV (T=1422K)  Etot = 0.886eV
# Energy per atom: Epot = 0.700eV  Ekin = 0.189eV (T=1460K)  Etot = 0.889eV
# Energy per atom: Epot = 0.692eV  Ekin = 0.188eV (T=1456K)  Etot = 0.880eV
# Energy per atom: Epot = 0.697eV  Ekin = 0.172eV (T=1330K)  Etot = 0.869eV
# Energy per atom: Epot = 0.676eV  Ekin = 0.188eV (T=1452K)  Etot = 0.864eV
# Energy per atom: Epot = 0.693eV  Ekin = 0.166eV (T=1284K)  Etot = 0.859eV
# Energy per atom: Epot = 0.692eV  Ekin = 0.179eV (T=1388K)  Etot = 0.872eV
# Energy per atom: Epot = 0.691eV  Ekin = 0.185eV (T=1433K)  Etot = 0.876eV
# Energy per atom: Epot = 0.711eV  Ekin = 0.158eV (T=1220K)  Etot = 0.869eV
# Energy per atom: Epot = 0.723eV  Ekin = 0.153eV (T=1185K)  Etot = 0.876eV
# Energy per atom: Epot = 0.688eV  Ekin = 0.186eV (T=1441K)  Etot = 0.874eV
# Energy per atom: Epot = 0.689eV  Ekin = 0.187eV (T=1446K)  Etot = 0.876eV
# Energy per atom: Epot = 0.705eV  Ekin = 0.178eV (T=1378K)  Etot = 0.883eV
# Energy per atom: Epot = 0.695eV  Ekin = 0.189eV (T=1462K)  Etot = 0.884eV
# Energy per atom: Epot = 0.682eV  Ekin = 0.207eV (T=1600K)  Etot = 0.889eV
# Energy per atom: Epot = 0.704eV  Ekin = 0.174eV (T=1343K)  Etot = 0.878eV
# Energy per atom: Epot = 0.683eV  Ekin = 0.182eV (T=1404K)  Etot = 0.865eV
# Energy per atom: Epot = 0.699eV  Ekin = 0.175eV (T=1350K)  Etot = 0.874eV
# Energy per atom: Epot = 0.683eV  Ekin = 0.189eV (T=1460K)  Etot = 0.872eV
# Energy per atom: Epot = 0.707eV  Ekin = 0.168eV (T=1299K)  Etot = 0.875eV
# Energy per atom: Epot = 0.701eV  Ekin = 0.182eV (T=1405K)  Etot = 0.883eV
# Energy per atom: Epot = 0.708eV  Ekin = 0.180eV (T=1395K)  Etot = 0.888eV
# Energy per atom: Epot = 0.705eV  Ekin = 0.179eV (T=1385K)  Etot = 0.884eV
# Energy per atom: Epot = 0.705eV  Ekin = 0.171eV (T=1325K)  Etot = 0.876eV
# Energy per atom: Epot = 0.698eV  Ekin = 0.179eV (T=1383K)  Etot = 0.877eV
# Energy per atom: Epot = 0.687eV  Ekin = 0.185eV (T=1430K)  Etot = 0.872eV
# Energy per atom: Epot = 0.684eV  Ekin = 0.184eV (T=1426K)  Etot = 0.869eV
# Energy per atom: Epot = 0.709eV  Ekin = 0.172eV (T=1328K)  Etot = 0.880eV
# Energy per atom: Epot = 0.705eV  Ekin = 0.175eV (T=1352K)  Etot = 0.880eV
# Energy per atom: Epot = 0.693eV  Ekin = 0.190eV (T=1472K)  Etot = 0.883eV
# Energy per atom: Epot = 0.695eV  Ekin = 0.190eV (T=1469K)  Etot = 0.884eV
# Energy per atom: Epot = 0.678eV  Ekin = 0.195eV (T=1512K)  Etot = 0.874eV
# Energy per atom: Epot = 0.704eV  Ekin = 0.177eV (T=1367K)  Etot = 0.881eV
# Energy per atom: Epot = 0.690eV  Ekin = 0.197eV (T=1522K)  Etot = 0.887eV
# Energy per atom: Epot = 0.698eV  Ekin = 0.185eV (T=1430K)  Etot = 0.883eV
# Energy per atom: Epot = 0.700eV  Ekin = 0.190eV (T=1472K)  Etot = 0.891eV
# Energy per atom: Epot = 0.743eV  Ekin = 0.144eV (T=1111K)  Etot = 0.887eV
# Energy per atom: Epot = 0.704eV  Ekin = 0.178eV (T=1375K)  Etot = 0.882eV
# Energy per atom: Epot = 0.708eV  Ekin = 0.170eV (T=1314K)  Etot = 0.878eV
# True

# %%
# NVT
"""Demonstrates molecular dynamics with constant temperature."""
from ase.lattice.cubic import FaceCenteredCubic
from ase.md.langevin import Langevin
from ase.io.trajectory import Trajectory
from ase import units
from ase.optimize import QuasiNewton
from ase.calculators.emt import EMT
from ase.md.velocitydistribution import (MaxwellBoltzmannDistribution,
                                         Stationary, ZeroRotation)
size = 3

T = 1500  # Kelvin

# Set up a crystal
atoms = FaceCenteredCubic(directions=[[1, 0, 0], [0, 1, 0], [0, 0, 1]],
                          symbol="Cu",
                          size=(size, size, size),
                          pbc=True)

# Describe the interatomic interactions with the Effective Medium Theory
atoms.calc = EMT()

# Do a quick relaxation
# qn = QuasiNewton(atoms)
# qn.run(fmax=0.001, steps=20)

MaxwellBoltzmannDistribution(atoms, temperature_K=T)
# Stationary(atoms)  # zero linear momentum
# ZeroRotation(atoms)  # zero angular momentum

# We want to run MD with constant energy using the Langevin algorithm
# with a time step of 5 fs, the temperature T and the friction
# coefficient to 0.02 atomic units.
dyn = Langevin(atoms, 5 * units.fs, T * units.kB, 0.002, logfile="moldyn4.log")


def printenergy(a=atoms):  # store a reference to atoms in the definition.
    """Function to print the potential, kinetic and total energy."""
    epot = a.get_potential_energy() / len(a)
    ekin = a.get_kinetic_energy() / len(a)
    print('Energy per atom: Epot = %.3feV  Ekin = %.3feV (T=%3.0fK)  '
          'Etot = %.3feV' % (epot, ekin, ekin / (1.5 * units.kB), epot + ekin))


dyn.attach(printenergy, interval=50)

# We also want to save the positions of all atoms after every 100th time step.
traj = Trajectory('moldyn4.traj', 'w', atoms)
dyn.attach(traj.write, interval=50)

# Now run the dynamics
dyn.run(1000)
# Out:
# e:\app\anaconda3\lib\site-packages\ase\md\md.py:48: FutureWarning: Specify the temperature in K using the 'temperature_K' argument
#   warnings.warn(FutureWarning(w))
# Energy per atom: Epot = -0.006eV  Ekin = 0.193eV (T=1489K)  Etot = 0.187eV
# Energy per atom: Epot = 0.076eV  Ekin = 0.118eV (T=910K)  Etot = 0.193eV
# Energy per atom: Epot = 0.088eV  Ekin = 0.118eV (T=913K)  Etot = 0.206eV
# Energy per atom: Epot = 0.098eV  Ekin = 0.112eV (T=869K)  Etot = 0.210eV
# Energy per atom: Epot = 0.104eV  Ekin = 0.115eV (T=887K)  Etot = 0.218eV
# Energy per atom: Epot = 0.123eV  Ekin = 0.113eV (T=876K)  Etot = 0.236eV
# Energy per atom: Epot = 0.130eV  Ekin = 0.108eV (T=836K)  Etot = 0.238eV
# Energy per atom: Epot = 0.110eV  Ekin = 0.141eV (T=1091K)  Etot = 0.251eV
# Energy per atom: Epot = 0.134eV  Ekin = 0.123eV (T=953K)  Etot = 0.257eV
# Energy per atom: Epot = 0.136eV  Ekin = 0.140eV (T=1081K)  Etot = 0.276eV
# Energy per atom: Epot = 0.142eV  Ekin = 0.136eV (T=1049K)  Etot = 0.278eV
# Energy per atom: Epot = 0.160eV  Ekin = 0.129eV (T=995K)  Etot = 0.288eV
# Energy per atom: Epot = 0.145eV  Ekin = 0.141eV (T=1091K)  Etot = 0.286eV
# Energy per atom: Epot = 0.148eV  Ekin = 0.145eV (T=1122K)  Etot = 0.293eV
# Energy per atom: Epot = 0.146eV  Ekin = 0.156eV (T=1206K)  Etot = 0.302eV
# Energy per atom: Epot = 0.169eV  Ekin = 0.139eV (T=1077K)  Etot = 0.308eV
# Energy per atom: Epot = 0.149eV  Ekin = 0.163eV (T=1261K)  Etot = 0.312eV
# Energy per atom: Epot = 0.150eV  Ekin = 0.171eV (T=1321K)  Etot = 0.320eV
# Energy per atom: Epot = 0.155eV  Ekin = 0.167eV (T=1292K)  Etot = 0.322eV
# Energy per atom: Epot = 0.162eV  Ekin = 0.170eV (T=1313K)  Etot = 0.332eV
# Energy per atom: Epot = 0.164eV  Ekin = 0.171eV (T=1326K)  Etot = 0.335eV
# True
